# %% [markdown]
# <a href="https://colab.research.google.com/github/dorothea-pudding/114-1_TAICA_homework/blob/main/1.%20%E7%95%AB%E5%87%BD%E6%95%B8%E5%9C%96%E5%BD%A2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#引入套件
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
#在線上顯示圖形(預設另開視窗)

# %%
a, b = 0, 0 #圓心座標
r = 3 #設定半徑
theta = np.linspace(0, 2*np.pi, 800) #產生角度(起始, 角度, 分割點數)
#算圓的描點座標
x = a + r * np.cos(theta)
y = b + r * np.sin(theta)
#x = np.linspace(-3*np.pi, 3*np.pi, 800) (函數起點, 函數終點, 描點個數) 這裡原本用來畫sin圖形，但是畫圓用不到
#y = np.log(x) #函數

# %%
plt.xkcd() #手繪風格

# %%
#import warnings 警告的相關套件
#warnings.filterwarnings("ignore")  忽略 UserWarning，但是不適用於底下找不到字型的警告
#ChatGPT的解釋：(字型警告)不是一般的 Python warnings，而是 Matplotlib 用 logging 模組輸出的訊息。所以你用 warnings.filterwarnings 沒有效果，因為它壓制的是 warnings，而不是 logging。

# %%
import logging #下個儲存格的警告是說找不到字型
logging.getLogger("matplotlib").setLevel(logging.ERROR) #這行用來隱藏那個警告

# %%
plt.gca().set_aspect('equal') #調整坐標軸比例
plt.plot(x, y) #畫函數圖
plt.show() #顯示圖片，在colab和jupyter已經整合(顯示最後一個圖片)，但是平常習慣有寫比較好

# %%
print(plt.style.available) #查看所有可用風格
#plt.style.use("名字") 引用預設風格，plt.xkcd()是開啟特殊的模擬手繪模式(ChatGPT的解釋)
